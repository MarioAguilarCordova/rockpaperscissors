# %%
import random 

color = input("What color is rose?: ")
print(color)

player_score = 0
computer_score = 0

# %%
print("Welcome to Rock, Paper, Scissors!")
game_total = input("Would you like to play best of 1, best of 3 or best of 5? Please respond with 1, 3 or 5")
print(game_total)

player = input("Rock, Paper or Scissors?")
print(player)

def game():
    
    player_choice()
    computer_choice()
    
def result(player, computer):
    if player == computer:
        return "Draw!" 
    elif player == "rock" and computer == "paper":
        computer_score += 1
        print()
        return "Point for Computer!"  
    
if player_score or computer_score == game_total:
    if player_score > computer_score:
        print("Player wins!")
    else:
        print("Computer wins!")
    answer = input("Would you like to play again? Y/N")
    play_again(answer)
# Out:
#   File "<ipython-input-13-516a60aea710>", line 11
#     if player ==
#                  ^
# SyntaxError: invalid syntax

# %%
print(random.randint(1,3))
print(random.randint(1,3))
# Out:
# 3
# 1

# %%
def computer_choice()
    computer = random.randint(1,3)
    if computer == 1:
        return "rock"
    elif computer == 2:
        return "paper"
    elif computer == 3:
        return "scissors"

# %%
def play_again(res):
    if answer == "Y":
        def play()
    else:
        return "Thank you for playing!"
# Out:
#   File "<ipython-input-12-91a34f616896>", line 3
#     def play()
#               ^
# SyntaxError: invalid syntax
